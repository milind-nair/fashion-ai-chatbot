otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_7_L1_view-all&cid=CI9JK83AKS5H'
linkBagSuitcaseLuggage='https://www.flipkart.com/all/~cs-xt03i9k5xc/pr?sid=all&collection-tab-name=Bags+and+Luggage&fm=neo%2Fmerchandising&iid=M_f499d27c-8e13-46c5-a712-a4c44a51d971_1_372UD5BXDFYS_MC.X8KIDQHRP5Q0&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Fashion~Bags%252C%2BSuitcases%2B%2526%2BLuggage_X8KIDQHRP5Q0&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=X8KIDQHRP5Q0'
linkKids='https://www.flipkart.com/clothing-and-accessories/pr?sid=clo&otracker=categorytree&p%5B%5D=facets.ideal_for%255B%255D%3DGirls&p%5B%5D=facets.ideal_for%255B%255D%3DBoys&p%5B%5D=facets.ideal_for%255B%255D%3DBoys%2B%2526%2BGirls&p%5B%5D=facets.ideal_for%255B%255D%3DBaby%2BBoys%2B%2526%2BBaby%2BGirls&p%5B%5D=facets.ideal_for%255B%255D%3DBaby%2BBoys&p%5B%5D=facets.ideal_for%255B%255D%3DBaby%2BGirls&otracker=nmenu_sub_Baby%20%26%20Kids_0_Kids%27%20Clothing&fm=neo%2Fmerchandising&iid=M_4de346f1-c5e1-4f56-beb0-7044fec76951_1_372UD5BXDFYS_MC.0QYFBACHTZGW&otracker=hp_rich_navigation_9_1.navigationCard.RICH_NAVIGATION_Fashion~Kids_0QYFBACHTZGW&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_9_L1_view-all&cid=0QYFBACHTZGW'

# %%
page = requests.get(linkTopMen)
page.content
df_links=[linkTopMen,linkBottomMen,linkEthnicWomen,linkWesternWomen,linkFootwearMen,linkFootwearWomen,linkWatchAccessories,linkBagSuitcaseLuggage,linkKids]

# %%
import pandas as pd
df=pd.DataFrame()

# %%
urls=[]
name=[]
price=[]
img=[]
brand=[]
features=[]
categ=[]

for j in range(9):
    try:
        page = requests.get(df_links[j])
        soup = bs(page.content, 'html.parser')
        print(j)
        l=0
        while(l!=5):

    #it gives us the visual representation of data
            for i in range(40):
                try:
                    if(j==7):
                        
                        div_element = soup.find_all('a', class_='_2rpwqI')[i]
                        #x=map(col col-3-12 _2H87wv,col col-9-12 _2vZqPX)
                    else:
                        div_element = soup.find_all('a', class_='_2UzuFa')[i]
                    
                    urls.append("https://www.flipkart.com" + str(div_element['href']))
                    pageInside = requests.get(urls[len(urls)-1])
                    soup1 = bs(pageInside.content, 'html.parser')
                    if(j!=7):
                        soup2 = soup1.find('div', class_='X3BRps')
                        if soup2 is None:
                            dict={}

                        else:
                            keys = soup2.select('div',class_='.col.col-3-12._2H87wv')
                            k=1    
                            dict={}
                            print(urls[len(urls)-1])
                            while k<len(keys)-1:
                        
                                key_text = keys[k].get_text().strip()
                                value_text = keys[k+1].get_text().strip()
                                k=k+3
                                dict[key_text]=value_text
                    else:
                            keys = soup1.select('td', class_='_1hKmbr col col-3-12')
                            keys = soup2.select('div',class_='.col.col-3-12._2H87wv')
                            k=1    
                            dict={}
                            print(urls[len(urls)-1])
                            while k<len(keys)-1:
                        
                                key_text = keys[k].get_text().strip()
                                value_text = keys[k+1].get_text().strip()
                                k=k+3
                                dict[key_text]=value_text


                        #print(f"Key: {key_text}\nValue: {value_text}\n")

                    name_element = soup1.find('span', class_='B_NuCI')
                    price_element = soup1.find('div', class_='_30jeq3')
                
                    price.append(price_element.text)
                #descrip_element=soup1.find('div', class_='_30jeq3')
                    img_elements = soup1.select('img[class*="_396"]')
                    img_element=''
                    for image in img_elements:
                        img_element = image['src']
                        
                
                    #_2r_T1I _396QI4
                    soup2=bs(str(soup1.find('span',class_='G6XhRU')),'html.parser')
                    brand_element=soup2.text.replace('\xa0', '')
                    brand.append(brand_element)
                    img.append(img_element)
                    name.append(name_element.text)
                                      

                    features.append(dict)
                    if(j==0):
                        categ.append("Men Top")
                    elif(j==1):
                        categ.append("Men Bottom")
                    elif(j==2):
                        categ.append("Women Ethnic")
                    elif(j==3):
                        categ.append("Women Western")
                    elif(j==4):
                        categ.append("Men Footwear")
                    elif(j==5):
                        categ.append("Women Footwear")
                    elif(j==6):
                        categ.append("Watch and Accessories")
                    elif(j==7):
                        categ.append("Luggages")
                    else:
                        categ.append("Kids")
                except AttributeError:
                # If 'div_element' is not found, exit the loop
                    break
        
            l+=1
            try:
                div_element = soup.find('a', class_='_1LKTO3')  
                pageInside = requests.get("https://www.flipkart.com" + str(div_element['href']))
                soup = bs(pageInside.content, 'html.parser')
            except AttributeError:
                # If 'div_element' is not found, exit the loop
                break
    except AttributeError:
                # If 'div_element' is not found, exit the loop
                break
# Out:
# 0
# https://www.flipkart.com/blue-martin-men-checkered-casual-white-black-dark-shirt/p/itm13dc9c6053f20?pid=SHTGM92WXNH2Q9GR&lid=LSTSHTGM92WXNH2Q9GRNIVA05&marketplace=FLIPKART&store=clo%2Fash&srno=b_1_1&otracker=browse&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_1_L1_view-all&fm=organic&iid=en_jPYThFGGKXBtNZLI4mY6q1NOiEgIpbfh_iFwMKeUFkJgjC47cwTIzI1TFjjLGktdBA7rKQ1Ppclchh0d4521EQ%3D%3D&ppt=None&ppn=None&ssid=yb3vlq6yv40000001692553141122
# https://www.flipkart.com/blue-martin-men-checkered-casual-multicolor-shirt/p/itme5df459eab0c0?pid=SHTGM92WRHUPGYYE&lid=LSTSHTGM92WRHUPGYYEYULBON&marketplace=FLIPKART&store=clo%2Fash&srno=b_1_2&otracker=browse&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_1_L1_view-all&fm=organic&iid=en_jPYThFGGKXBtNZLI4mY6q1NOiEgIpbfh_iFwMKeUFkKF_xVkUdsBA5-pv5WYC-UnM9L7wGntx6WgIoRksok2lw%3D%3D&ppt=None&ppn=None&ssid=yb3vlq6yv40000001692553141122
# ...

# %%
df['pdt_url']=urls
df['pdt_name']=name
df['pdt_categ']=categ
df['price']=price
df['pdt_img']=img
df['brand']=brand
df['Features']=features

# %%
df
# Out:
#                                                 pdt_url  \
# 0     https://www.flipkart.com/blue-martin-men-check...
# 1     https://www.flipkart.com/blue-martin-men-check...
# 2     https://www.flipkart.com/ausk-striped-men-roun...
# 3     https://www.flipkart.com/ausk-striped-men-roun...
# 4     https://www.flipkart.com/surhi-men-checkered-c...
# ...                                                 ...
# 1795  https://www.flipkart.com/fasla-short-boys-casu...
# 1796  https://www.flipkart.com/x2o-track-pant-boys/p...
# 1797  https://www.flipkart.com/smartraho-boys-casual...
# 1798  https://www.flipkart.com/disney-icable-baby-gi...
# 1799  https://www.flipkart.com/fasla-short-boys-casu...
#
#                                                pdt_name pdt_categ  \
# 0     Men Regular Fit Checkered Spread Collar Casual...   Men Top
# 1     Men Regular Fit Checkered Spread Collar Casual...   Men Top
# 2     Men Striped Round Neck Cotton Blend Blue, Blac...   Men Top
# ...

# %%
excel_file_name = 'flipkartProduct.xlsx'
# Convert the DataFrame to an Excel file
df.to_excel(excel_file_name, index=False)
